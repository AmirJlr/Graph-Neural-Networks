# %% [markdown]
# # Introduction To NetworkX

# %%
import networkx as nx

# %%
### define Graph G

G = nx.Graph()
G.add_nodes_from([1, 2, 3, 4])
G.add_edges_from([(1,2), (1, 3), (2,3), (2, 4), (2, 5)])
nx.draw(G)

# %%
# Nodes - vertices
G.nodes
# Out:
# NodeView((1, 2, 3, 4, 5))

# %%
G.number_of_nodes()
# Out:
# 5

# %%
# edges
G.edges
# Out:
# EdgeView([(1, 2), (1, 3), (2, 3), (2, 4), (2, 5)])

# %%
G.number_of_edges()
# Out:
# 5

# %%
G.graph
# Out:
# {}

# %%
# export graph :

from networkx.readwrite import json_graph

# %%
# export data(in json)
json_data = json_graph.node_link_data(G)
json_data
# Out:
# {'directed': False,
#  'multigraph': False,
#  'graph': {},
#  'nodes': [{'id': 1}, {'id': 2}, {'id': 3}, {'id': 4}, {'id': 5}],
#  'links': [{'source': 1, 'target': 2},
#   {'source': 1, 'target': 3},
#   {'source': 2, 'target': 3},
#   {'source': 2, 'target': 4},
#   {'source': 2, 'target': 5}]}

# %%
# export graph
data_to_graph = json_graph.node_link_graph(json_data)
data_to_graph

# %%
nx.draw(data_to_graph)

# %%
G.is_directed()
# Out:
# False

# %%
G.is_multigraph()
# Out:
# False

# %%
# number og nodes :
G.order()
# Out:
# 5

# %%
# Density of Graph (?)
from networkx.classes.function import density
density(G)
# Out:
# 0.5

# %%
# Degree of Graph
from networkx.classes.function import degree
degree(G)
# Out:
# DegreeView({1: 2, 2: 4, 3: 2, 4: 1, 5: 1})

# %%
from networkx.classes.function import degree_histogram
degree_histogram(G)

# frequency of degree
# Out:
# [0, 2, 2, 0, 1]

# %%
# Neighbors :
from networkx.classes.function import neighbors

for node in G.nodes():
    print(f"Node : {node} is Neighbor with : {list(neighbors(G, node))}")
# Out:
# Node : 1 is Neighbor with : [2, 3]
# Node : 2 is Neighbor with : [1, 3, 4, 5]
# Node : 3 is Neighbor with : [1, 2]
# Node : 4 is Neighbor with : [2]
# Node : 5 is Neighbor with : [2]

# %%
### path Graph

# %% [markdown]
# ### Directional Graph
#
# `nx.DiGraph()`

# %%
di_graph = nx.DiGraph()

di_graph.add_edges_from([(1, 2), (2, 3)])

nx.draw(di_graph)

# %%
nx.is_directed(di_graph)
# Out:
# True

# %%
nx.is_weighted(di_graph)
# Out:
# False

# %%
di_graph.nodes
# Out:
# NodeView((1, 2, 3))

# %% [markdown]
# ## Neighbor & Adjacency
